# %%
from photutils import DAOStarFinder
from astropy.io import fits
from matplotlib import pyplot as plt
from photutils import aperture_photometry, CircularAperture, CircularAnnulus
import numpy as np
from glob import glob

# %matplotlib inline

# %%
image= fits.open("O120308_0175.fits")
image_pixels = image[0].data

plt.imshow(image_pixels, vmin=2000, vmax=4000)
plt.colorbar()

# %%
daofind = DAOStarFinder(fwhm=4., threshold=1000)
starlist = daofind(image_pixels)

# %%
plt.scatter(starlist['xcentroid'], starlist['ycentroid'])
print (len(starlist))
# Out:
# 24

# %%
plt.imshow(image_pixels, vmin=2000, vmax=4000)
for row in starlist:
    plt.scatter(row['xcentroid'], row['ycentroid'], alpha=0.3, color='red')
    plt.text(row['xcentroid'], row['ycentroid'], row['id'])
    
#plt.xlim(1200,1800)
#plt.ylim(500,1000)

# %% [markdown]
# B = 19
# C = 18
# D = 12

# %%
positions = np.transpose((starlist['xcentroid'], starlist['ycentroid']))

aperture = CircularAperture(positions, r=6.)
annulus_aperture = CircularAnnulus(positions, r_in=10., r_out=15.)
apers = [aperture, annulus_aperture]

phot_table = aperture_photometry(image, apers)

bkg_mean = phot_table['aperture_sum_1'] / annulus_aperture.area
bkg_sum = bkg_mean * aperture.area

final_sum = phot_table['aperture_sum_0'] - bkg_sum
# Out:
# WARNING: AstropyDeprecationWarning: "astropy.io.fits.PrimaryHDU", "astropy.io.fits.ImageHDU", and "astropy.io.fits.HDUList" inputs are deprecated as of v0.7 and will not be allowed in future versions. [photutils.aperture._photometry_utils]
# WARNING: Input data is a HDUList object.  Doing photometry only on the 0 HDU. [photutils.aperture._photometry_utils]
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 55995.000000 from DATE-OBS.
# Changed DATE-OBS from '2012-03-09        ' to '2012-03-09T00:00:00.0''. [astropy.wcs.wcs]

# %%
magnitudes = -2.5*np.log10(final_sum)
magnitudes
# Out:
# <Column name='aperture_sum_0' dtype='float64' length=24>
# -11.874471131332811
#  -14.49866778563053
# -12.949797988042366
# -14.416270192782804
#  -15.53716944194204
# -12.850358769667952
# -14.628445905894495
# -14.736242795064832
#   -13.6358570514556
# -14.911435793618368
# -13.444282065652327
# -14.689701216590542
#  -9.777463230530213
# -13.391142569332391
# -13.977328068411977
#  -13.23112514863169
# -12.914911970363473
# -15.545805651036385
# -14.132060229480452
# -13.554110778012088
# -13.843429791002837
# -14.001332020441229
# -11.840381464264361
# -11.886958805612657

# %%
starlist
# Out:
# <Table length=24>
#   id      xcentroid      ...        flux                 mag
# int64      float64       ...      float64              float64
# ----- ------------------ ... ------------------ ---------------------
#     1  2095.372098528767 ... 2.5090643855581147    -0.998779514918479
#     2 1633.6214255960404 ...  4.831483215008578   -1.7102011877533099
#     3  554.7284681507963 ... 1.3817949787189658   -0.3511090254387138
#     4  1273.542736781841 ...   4.44702768169719   -1.6201745820948585
#     5   769.504270160087 ...  13.74908521204345    -2.845684508946977
#     6  1711.095562406336 ... 1.0088416058989083 -0.009557461964968888
#     7 1042.5042835591382 ...  5.754463903877824    -1.900012175504264
#     8 1710.0302920134645 ...  5.490441243628424   -1.8490181206755751
#     9  89.04659629667336 ...   2.30258703873935   -0.9055401392240798
#    10  1495.425709213584 ...  6.897456599896558   -2.0967224412416905
# ...

# %%
ZP_B = 15.1 - magnitudes[19-1]  # B (15.1)
ZP_C = 13.7 - magnitudes[18-1]    # C (13.7)
ZP_D = 13.7 - magnitudes[12-1]    # D (13.7)

# %%
print (ZP_B, ZP_C, ZP_D)
# Out:
# 29.232060229480453 29.245805651036385 28.38970121659054

# %%
avg_ZP = np.average([ZP_B, ZP_C])
avg_ZP
# Out:
# 29.23893294025842

# %%
mag_NNSer = magnitudes[14-1] + avg_ZP

# %%
print (mag_NNSer)
# Out:
# 15.847790370926027

# %%
apers
# Out:
# [<CircularAperture([[2.09537210e+03, 1.58803252e+00],
#                     [1.63362143e+03, 2.41929973e+01],
#                     [5.54728468e+02, 1.41438689e+02],
#                     [1.27354274e+03, 2.55753717e+02],
#                     [7.69504270e+02, 4.21289792e+02],
#                     [1.71109556e+03, 5.91353729e+02],
#                     [1.04250428e+03, 6.43432444e+02],
#                     [1.71003029e+03, 7.22782724e+02],
#                     [8.90465963e+01, 7.57684732e+02],
#                     [1.49542571e+03, 7.85642439e+02],
#                     [7.82630318e+02, 8.22567601e+02],
#                     [1.42914433e+03, 8.39408841e+02],
#                     [2.06645054e+03, 1.05317210e+03],
#                     [1.38817655e+03, 1.15111573e+03],
#                     [1.75203032e+03, 1.24134545e+03],
#                     [1.74616548e+03, 1.24912450e+03],
#                     [1.28457211e+02, 1.45482537e+03],
# ...

# %%
files = glob("O*")

results =[]

for file in files:
    
    print (file)
    
    image= fits.open(file)
    image_pixels = image[0].data

    phot_table = aperture_photometry(image, apers)

    bkg_mean = phot_table['aperture_sum_1'] / annulus_aperture.area
    bkg_sum = bkg_mean * aperture.area

    final_sum = phot_table['aperture_sum_0'] - bkg_sum
    
    magnitudes = -2.5*np.log10(final_sum)
    
    ZP_B = 15.1 - magnitudes[19-1]  # B (15.1)
    ZP_C = 13.7 - magnitudes[18-1]    # C (13.7)
    ZP_D = 13.7 - magnitudes[12-1]    # D (13.7)
    
    avg_ZP = np.average([ZP_B, ZP_C])
    mag_NNSer = magnitudes[14-1] + avg_ZP
    
    results.append(mag_NNSer)
    print (mag_NNSer)
# Out:
# O120308_0183.fits
# 15.846328744293832
# O120308_0176.fits
# 15.849566353869267
# O120308_0177.fits
# 15.83363671771065
# O120308_0182.fits
# 15.856052177589493
# O120308_0189.fits
# 15.85484079552602
# O120308_0185.fits
# 15.848487414560541
# O120308_0192.fits
# WARNING: AstropyDeprecationWarning: "astropy.io.fits.PrimaryHDU", "astropy.io.fits.ImageHDU", and "astropy.io.fits.HDUList" inputs are deprecated as of v0.7 and will not be allowed in future versions. [photutils.aperture._photometry_utils]
# WARNING: Input data is a HDUList object.  Doing photometry only on the 0 HDU. [photutils.aperture._photometry_utils]
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'PRESSURE' is not FITS standard (invalid value string: "'                768 / Barometric pressure").  Fixed 'PRESSURE' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
# ...

# %%
plt.plot(results, marker='o')

plt.ylim(20, 10)
# Out:
# (20, 10)

# %%
image= fits.open("O120308_0185.fits")
image_pixels = image[0].data

plt.imshow(image_pixels, vmin=3500, vmax=4000)
plt.colorbar()
plt.xlim(1000,2000)
plt.ylim(500,1500)

plt.scatter(row['xcentroid'], row['ycentroid'], alpha=0.3, color='red')
